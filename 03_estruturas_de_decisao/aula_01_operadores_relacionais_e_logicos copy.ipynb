# %% [markdown]
# # 📓 Aula 01: Operadores Relacionais e Lógicos
#
# ### 🎯 Objetivo da Aula
# Compreender como comparar valores e combinar múltiplas condições lógicas que resultam em valores booleanos (`True` ou `False`).
#
# ---
#
# ## 1. Operadores Relacionais (Comparação)
#
# | Operador | Significado | Exemplo | Resultado |
# | :---: | :--- | :--- | :---: |
# | `==` | Igual a | `5 == 5` | `True` |
# | `!=` | Diferente de | `5 != 3` | `True` |
# | `>` | Maior que | `10 > 20` | `False` |
# | `<` | Menor que | `10 < 20` | `True` |
# | `>=` | Maior ou igual a | `7 >= 7` | `True` |
# | `<=` | Menor ou igual a | `4 <= 3` | `False` |

# %%
# Exemplos de comparações
idade = 17
tem_titulo = True

print("Maior de idade?", idade >= 18)
print("Idade diferente de 18?", idade != 18)

# %% [markdown]
# ## 2. Operadores Lógicos
#
# * **`and` (E):** Retorna `True` **apenas** se todas as condições forem verdadeiras.
# * **`or` (OU):** Retorna `True` se **pelo menos uma** condição for verdadeira.
# * **`not` (NÃO):** Inverte o valor lógico (`True` vira `False` e vice-versa).
#
# ### Tabela-Verdade Resumida:
# * `True and True` ➔ `True`
# * `True and False` ➔ `False`
# * `False or True` ➔ `True`
# * `False or False` ➔ `False`
# * `not True` ➔ `False`

# %%
# Exemplo de verificação de permissão
aluno_matriculado = True
mensalidade_em_dia = True
tem_carteirinha = False

pode_entrar_no_lab = aluno_matriculado and (mensalidade_em_dia or tem_carteirinha)
print("Acesso autorizado ao laboratório?", pode_entrar_no_lab)

# %% [markdown]
# ## 🛠️ Prática do Aluno (Mão na Massa)
# Declare variáveis para representar:
# * `media_aluno` (nota de 0 a 10)
# * `frequencia_percentual` (frequência de 0 a 100)
#
# Crie uma expressão lógica que verifique se o aluno foi aprovado (critério da escola: média maior ou igual a 6.0 **E** frequência maior ou igual a 75%).

# %%
# TODO: Implemente a expressão de validação
media_aluno = 7.5
frequencia_percentual = 80

# Crie a variável aprovado com a expressão lógica
aprovado = None # Substitua None pela expressão lógica
print("Status de aprovação:", aprovado)
