# %% [markdown]
# # 📓 Aula 01: Variáveis e Tipos Primitivos de Dados
#
# ### 🎯 Objetivo da Aula
# Aprender como o computador armazena informações na memória RAM, como o Python reconhece tipos de forma dinâmica e como inspecionar esses dados usando a função `type()`.
#
# ---
#
# ### 🔍 O Cenário da Investigação (Missão Casas Paulino)
# Nossa escola assumiu um projeto para digitalizar a gestão de clientes e anúncios da loja **Casas Paulino** em Tianguá. Precisamos cadastrar:
# * Nome do cliente
# * Idade
# * Valor investido em compras
# * Se o cadastro está ativo ou inativo

# %% [markdown]
# ## 1. O que são Variáveis?
# Variáveis são como gavetas etiquetadas na memória do computador. Em Python, a variável é criada automaticamente no momento em que atribuímos um valor a ela com o operador de atribuição `=`.
#
# ### Tipos Primitivos:
# * **`str` (String):** Textos delimitados por aspas simples `' '` ou duplas `" "`.
# * **`int` (Inteiro):** Números inteiros positivos ou negativos (sem casas decimais).
# * **`float` (Ponto Flutuante):** Números reais/decimais. Em Python usamos o ponto (`.`) como separador decimal.
# * **`bool` (Booleano):** Valores lógicos: `True` (Verdadeiro) ou `False` (Falso).

# %%
# Exemplo do Professor: Criando variáveis para o cliente
nome_cliente = "Maria das Dores"       # str
idade_cliente = 28                    # int
valor_compras = 249.90                # float
cadastro_ativo = True                 # bool

# Inspecionando os tipos armazenados na memória
print("Tipo do nome:", type(nome_cliente))
print("Tipo da idade:", type(idade_cliente))
print("Tipo do valor:", type(valor_compras))
print("Tipo do cadastro:", type(cadastro_ativo))
# Out:
# Tipo do nome: <class 'str'>
# Tipo da idade: <class 'int'>
# Tipo do valor: <class 'float'>
# Tipo do cadastro: <class 'bool'>

# %% [markdown]
# ## 2. Regras de Nomenclatura no Python (PEP 8)
# * Use nomes descritivos em letras minúsculas separadas por sublinhado: `snake_case` (ex: `valor_total`, `taxa_servico`).
# * **Não pode** começar com números (ex: `1nota` ❌).
# * **Não pode** conter espaços (ex: `nome cliente` ❌).
# * **Não pode** conter caracteres especiais como acentos ou cedilha (ex: `preço` ❌ -> use `preco` ✅).
# * Não use palavras reservadas do Python (como `if`, `for`, `print`, `class`).

# %% [markdown]
# ## 🛠️ Prática do Aluno (Mão na Massa)
# Agora é a sua vez! Crie 4 variáveis para cadastrar um novo produto no estoque de informática da escola:
# 1. `nome_produto` (texto)
# 2. `quantidade_estoque` (inteiro)
# 3. `preco_unitario` (ponto flutuante)
# 4. `disponivel_para_venda` (booleano)
#
# Em seguida, exiba o valor de cada uma e seu respectivo tipo usando `print()` e `type()`.

# %%
# TODO: Declare as variáveis abaixo e execute a célula para testar
nome_produto = ""
quantidade_estoque = 0
preco_unitario = 0.0
disponivel_para_venda = False

# TODO: Escreva os prints de inspeção aqui
